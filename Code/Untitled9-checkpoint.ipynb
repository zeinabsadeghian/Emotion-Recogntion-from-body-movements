# %%
import bvh
from bvh import Bvh
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
with open('Session2_AnBh-012_130_564708_567558_2850_Joy.bvh') as f:
    mocap = Bvh(f.read())

# %%
len(mocap.get_joints_names())
# Out:
# 23

# %%
x = []
y = []
z = []

# %%
x.append(mocap.joint_offset('Neck')[0])
y.append(mocap.joint_offset('Neck')[1])
z.append(mocap.joint_offset('Neck')[2])

x.append(mocap.joint_offset('LeftWrist')[0])
y.append(mocap.joint_offset('LeftWrist')[1])
z.append(mocap.joint_offset('LeftWrist')[2])

x.append(mocap.joint_offset('LeftElbow')[0])
y.append(mocap.joint_offset('LeftElbow')[1])
z.append(mocap.joint_offset('LeftElbow')[2])

x.append(mocap.joint_offset('LeftShoulder')[0])
y.append(mocap.joint_offset('LeftShoulder')[1])
z.append(mocap.joint_offset('LeftShoulder')[2])

x.append(mocap.joint_offset('LeftCollar')[0])
y.append(mocap.joint_offset('LeftCollar')[1])
z.append(mocap.joint_offset('LeftCollar')[2])

x.append(mocap.joint_offset('RightWrist')[0])
y.append(mocap.joint_offset('RightWrist')[1])
z.append(mocap.joint_offset('RightWrist')[2])

x.append(mocap.joint_offset('RightElbow')[0])
y.append(mocap.joint_offset('RightElbow')[1])
z.append(mocap.joint_offset('RightElbow')[2])

x.append(mocap.joint_offset('RightShoulder')[0])
y.append(mocap.joint_offset('RightShoulder')[1])
z.append(mocap.joint_offset('RightShoulder')[2])

x.append(mocap.joint_offset('RightCollar')[0])
y.append(mocap.joint_offset('RightCollar')[1])
z.append(mocap.joint_offset('RightCollar')[2])

x.append(mocap.joint_offset('Hips')[0])
y.append(mocap.joint_offset('Hips')[1])
z.append(mocap.joint_offset('Hips')[2])

x.append(mocap.joint_offset('Chest')[0])
y.append(mocap.joint_offset('Chest')[1])
z.append(mocap.joint_offset('Chest')[2])

x.append(mocap.joint_offset('Chest2')[0])
y.append(mocap.joint_offset('Chest2')[1])
z.append(mocap.joint_offset('Chest2')[2])

x.append(mocap.joint_offset('Chest3')[0])
y.append(mocap.joint_offset('Chest3')[1])
z.append(mocap.joint_offset('Chest3')[2])

x.append(mocap.joint_offset('Chest4')[0])
y.append(mocap.joint_offset('Chest4')[1])
z.append(mocap.joint_offset('Chest4')[2])

x.append(mocap.joint_offset('Head')[0])
y.append(mocap.joint_offset('Head')[1])
z.append(mocap.joint_offset('Head')[2])

x.append(mocap.joint_offset('RightHip')[0])
y.append(mocap.joint_offset('RightHip')[1])
z.append(mocap.joint_offset('RightHip')[2])

x.append(mocap.joint_offset('RightKnee')[0])
y.append(mocap.joint_offset('RightKnee')[1])
z.append(mocap.joint_offset('RightKnee')[2])

x.append(mocap.joint_offset('RightAnkle')[0])
y.append(mocap.joint_offset('RightAnkle')[1])
z.append(mocap.joint_offset('RightAnkle')[2])

x.append(mocap.joint_offset('RightToe')[0])
y.append(mocap.joint_offset('RightToe')[1])
z.append(mocap.joint_offset('RightToe')[2])

x.append(mocap.joint_offset('LeftHip')[0])
y.append(mocap.joint_offset('LeftHip')[1])
z.append(mocap.joint_offset('LeftHip')[2])

x.append(mocap.joint_offset('LeftKnee')[0])
y.append(mocap.joint_offset('LeftKnee')[1])
z.append(mocap.joint_offset('LeftKnee')[2])

x.append(mocap.joint_offset('LeftAnkle')[0])
y.append(mocap.joint_offset('LeftAnkle')[1])
z.append(mocap.joint_offset('LeftAnkle')[2])

x.append(mocap.joint_offset('LeftToe')[0])
y.append(mocap.joint_offset('LeftToe')[1])
z.append(mocap.joint_offset('LeftToe')[2])

# %%
print(np.array(x))
print(np.array(y))
print(np.array(z))
# Out:
# [  0.       0.       0.      13.6645   2.9201   0.       0.     -13.6645
#   -2.9201   0.       0.       0.       0.       0.       0.      -7.7973
#    0.       0.       0.       7.7973   0.       0.       0.    ]
# [ 1.43751e+01 -2.42536e+01 -2.99992e+01  0.00000e+00  9.51880e+00
#  -2.42536e+01 -2.99992e+01  0.00000e+00  9.51880e+00  0.00000e+00
#   9.58100e+00  9.56110e+00  9.52110e+00  9.51140e+00  8.90120e+00
#   5.30000e-03 -4.06634e+01 -3.95237e+01 -6.41800e+00  5.30000e-03
#  -4.06634e+01 -3.95237e+01 -6.41800e+00]
# [ 0.00000e+00  0.00000e+00  0.00000e+00  0.00000e+00  0.00000e+00
#   0.00000e+00  0.00000e+00  0.00000e+00  0.00000e+00  0.00000e+00
#  -1.10000e-03  2.20000e-03  0.00000e+00  0.00000e+00  4.60000e-03
#   5.00000e-04 -5.00000e-04 -9.00000e-04  1.44853e+01  5.00000e-04
#  -5.00000e-04 -9.00000e-04  1.44853e+01]

# %%
x1 = []
y1 = []
z1 = []
print(mocap.nframes)

for i in range(0,72):
    if i%3 == 0:
        x1.append(mocap.frames[340][i])
    elif i%3 == 1:
        y1.append(mocap.frames[340][i])
    elif i%3 == 2:
        z1.append(mocap.frames[340][i])
# Out:
# 343

# %%
print(x1)
print(y1)
print(z1)
# Out:
# ['-14.026186', '-167.755809', '-2.117214', '-0.353724', '-0.560510', '-1.741107', '10.210449', '10.717384', '1.141871', '6.014490', '-70.983806', '0.103736', '-8.392871', '-3.269063', '66.672827', '-0.509018', '-5.315300', '-5.346241', '8.534744', '0.000452', '6.070133', '128.257051', '6.473151', '0.006395']
# ['126.913858', '-48.438525', '25.771261', '4.210966', '6.716254', '21.237906', '18.084222', '-6.177021', '3.472968', '-12.269911', '-55.583993', '17.534383', '0.296225', '-3.549448', '-55.377302', '-6.551056', '-24.209490', '78.699329', '-15.095433', '-0.003105', '5.514789', '65.337782', '12.017719', '-0.005576']
# ['25.813748', '-2.172775', '0.640826', '0.161375', '0.244987', '0.612963', '2.340631', '0.267837', '1.267732', '-9.429455', '126.111190', '-1.166345', '0.295312', '11.702073', '-117.680320', '2.620158', '-6.357109', '-4.972291', '2.524700', '0.000200', '0.885196', '147.676962', '0.116138', '0.002833']

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')
#ax1.plot_wireframe(np.array(x), np.array(y), np.array(z))
ax1.set_xlabel('x axis')
ax1.set_ylabel('y axis')
ax1.set_zlabel('z axis')
ax1.scatter3D(np.array(x), np.array(y), np.array(z))
#plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pymo

# %%
 next(mocap.root.filter('ROOT'))
# Out:
# ROOT Hips

# %%
import pandas as pd

# %%
with open('20170902_085505_00.txt') as s:
    m = s.read()

# %%
spli = m.split('\n')
spli[0].split(';')
# Out:
# ['frameTime',
#  'bodyIndex',
#  'SpineBase_positionX',
#  'SpineBase_positionY',
#  'SpineBase_positionZ',
#  'SpineBase_rotationX',
#  'SpineBase_rotationY',
#  'SpineBase_rotationZ',
#  'SpineMid_positionX',
#  'SpineMid_positionY',
#  'SpineMid_positionZ',
#  'SpineMid_rotationX',
#  'SpineMid_rotationY',
#  'SpineMid_rotationZ',
#  'Neck_positionX',
#  'Neck_positionY',
#  'Neck_positionZ',
#  'Neck_rotationX',
#  'Neck_rotationY',
#  'Neck_rotationZ',
#  'Head_positionX',
#  'Head_positionY',
#  'Head_positionZ',
#  'Head_rotationX',
#  'Head_rotationY',
#  'Head_rotationZ',
#  'ShoulderLeft_positionX',
#  'ShoulderLeft_positionY',
#  'ShoulderLeft_positionZ',
#  'ShoulderLeft_rotationX',
#  'ShoulderLeft_rotationY',
#  'ShoulderLeft_rotationZ',
#  'ElbowLeft_positionX',
#  'ElbowLeft_positionY',
#  'ElbowLeft_positionZ',
#  'ElbowLeft_rotationX',
#  'ElbowLeft_rotationY',
#  'ElbowLeft_rotationZ',
#  'WristLeft_positionX',
#  'WristLeft_positionY',
#  'WristLeft_positionZ',
# ...

# %%
x = open("quick3.csv", "w+")

# %%
for i in range(0, len(spli)):
    tmp = []
    tmp = spli[i].split(';')
    for i in range(0, len(tmp)):
        x.write(tmp[i])
        x.write(",")
    x.write("\n")

# %%
x.close
# Out:
# <function TextIOWrapper.close()>

# %%
import pandas as pd
file = pd.read_csv("quick3.csv")
file

# %%
list_x = []
list_y = []
list_z = []
for i in range(0, len(file.columns)):
    if file.columns[i].find("positionX") > -1:
        list_x.append(file[file.columns[i]])
        
    if file.columns[i].find("positionY") > -1:
        list_y.append(file[file.columns[i]])
        
    if file.columns[i].find("positionZ") > -1:
        list_z.append(file[file.columns[i]])

# %%
n = 0
for i in range(0, len(file.columns)):
    if file.columns[i].find("positionX") > -1:
        n = n + 1
        print(n)
        print(file.columns[i])
# Out:
# 1
# SpineBase_rotationX
# 2
# SpineMid_rotationX
# 3
# Neck_rotationX
# 4
# Head_rotationX
# 5
# ShoulderLeft_rotationX
# 6
# ElbowLeft_rotationX
# 7
# WristLeft_rotationX
# 8
# HandLeft_rotationX
# 9
# ShoulderRight_rotationX
# 10
# ElbowRight_rotationX
# 11
# WristRight_rotationX
# 12
# HandRight_rotationX
# 13
# HipLeft_rotationX
# 14
# KneeLeft_rotationX
# 15
# AnkleLeft_rotationX
# 16
# FootLeft_rotationX
# 17
# HipRight_rotationX
# 18
# KneeRight_rotationX
# 19
# AnkleRight_rotationX
# 20
# FootRight_rotationX
# 21
# SpineShoulder_rotationX
# 22
# HandTipLeft_rotationX
# 23
# ThumbLeft_rotationX
# 24
# HandTipRight_rotationX
# 25
# ThumbRight_rotationX

# %%
len(list_x)
# Out:
# 25

# %%
x = []
y = []
z = []
for i in range(0, len(list_x)):
        x.append(list_x[i][0])
        
for i in range(0, len(list_y)):
        y.append(list_y[i][0])

for i in range(0, len(list_z)):
        z.append(list_z[i][0])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')
#ax1.plot_wireframe(np.array(x), np.array(y), np.array(z))
ax1.set_xlabel('x axis')
ax1.set_ylabel('y axis')
ax1.set_zlabel('z axis')
ax1.scatter3D(np.array(x), np.array(y), np.array(z))
#plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(x, y, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-5caea0f2550c> in <module>()
# ----> 1 plt.scatter(x, y, alpha=0.5)
#       2 plt.title('Scatter plot pythonspot.com')
#       3 plt.xlabel('x')
#       4 plt.ylabel('y')
#       5 plt.show()
#
# ~\Anaconda3\envs\tensorflow1\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~\Anaconda3\envs\tensorflow1\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
# ...

# %%
#%matplotlib notebook
